# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# %% [markdown]
# ### 导入raw data

# %%
champs=pd.read_csv('input/champs.csv',encoding='utf-8')
matches=pd.read_csv('input/matches.csv',encoding='utf-8')
participants=pd.read_csv('input/participants.csv',encoding='utf-8')
stats1=pd.read_csv('input/stats1.csv',encoding='utf-8')
stats2=pd.read_csv('input/stats2.csv',encoding='utf-8')
stats_all = stats1.append(stats2)
# Out:
# D:\DevTools\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (52) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### 合并raw data

# %%
df = pd.merge(participants,stats_all, how = 'left', on = ['id'], suffixes=('', '_stats'))
df = pd.merge(df , champs, how = 'left', left_on= 'championid', right_on='id',suffixes=('', '_champs') )
df = pd.merge(df, matches, how = 'left', left_on = 'matchid', right_on = 'id', suffixes=('', '_matches'))

# %% [markdown]
# ### 数据预处理

# %%
def final_position(col):
    if col['role'] in ('DUO_SUPPORT', 'DUO_CARRY'):
        return col['role']
    else:
        return col['position']

# %%
df['adjposition'] = df.apply(final_position, axis = 1)
df['team'] = df['player'].apply(lambda x: '1' if x <= 5 else '2')
df['team_role'] = df['team'] + ' - ' + df['adjposition']

# %%
remove_index = []
for i in ('1 - MID', '1 - TOP', '1 - DUO_SUPPORT', '1 - DUO_CARRY', '1 - JUNGLE',
          '2 - MID', '2 - TOP', '2 - DUO_SUPPORT', '2 - DUO_CARRY', '2 - JUNGLE'):
    df_remove = df[df['team_role'] == i].groupby('matchid').agg({'team_role':'count'})
    remove_index.extend(df_remove[df_remove['team_role'] != 1].index.values)
# remove unclassified BOT, correct ones should be DUO_SUPPORT OR DUO_CARRY
remove_index.extend(df[df['adjposition'] == 'BOT']['matchid'].unique())
remove_index = list(set(remove_index))

print('# matches in dataset before cleaning:{}'.format(df['matchid'].nunique()))
df = df[~df['matchid'].isin(remove_index)]
print('# matches in dataset after cleaning: {}'.format(df['matchid'].nunique()))
print('row_num',df.shape[0])
# Out:
# # matches in dataset before cleaning:184069
# # matches in dataset after cleaning: 148638
# row_num 1486362

# %%
#缺失值删除
df_null=df[df.isnull().values==True]
matchids=list(df_null['matchid'].drop_duplicates())
df = df[~df.matchid.isin(matchids)]

# %% [markdown]
# ### 对局信息

# %%
##################################################################################
#                        df_3：对局信息                                           #
##################################################################################
df_3 = df[['matchid', 'player', 'name', 'team_role', 'win']]
df_3 = df_3.pivot(index= 'matchid', columns= 'team_role', values= 'name')
df_3 = df_3.reset_index()
df_3 = df_3.merge(df[df['player'] == 1][['matchid', 'win']], left_on = 'matchid', right_on = 'matchid', how = 'left')
#df_3 = df_3[df_3.columns.difference(['matchid'])]
df_3 = df_3.rename(columns = {'win': 'T1 win'})
df_3 = df_3.dropna()
#print(df_3.isnull().any())

# %% [markdown]
# ### 构造英雄特征

# %%
def extracting(df,df_3):
#     #按matchid, team提取total_kills
#     df_tk = df[['kills']].groupby([df['matchid'],df['team']]).sum().rename(columns={'kills':'total_kills'}).reset_index()
#     df_tk['team'] = df_tk['team'].astype('int64')

    #按name提取k,d,a,KDA,dtoturrets, visionscore
    dfcht = df[['name','kills','deaths','assists','dmgtoturrets','visionscore']].groupby('name').mean()
    dfcht['KDA'] = (dfcht['kills']+dfcht['assists'])/dfcht['deaths']

    #将信息与df_3合并
#     df_4 = df_3.merge(df_tk[df_tk['team']==1][['matchid','total_kills']].rename(columns={'total_kills':'1_total_kills'}), on = 'matchid',how='left')\
#             .merge(df_tk[df_tk['team']==2][['matchid','total_kills']].rename(columns={'total_kills':'2_total_kills'}), on = 'matchid',how='left')
    df_4 = df_3
    df_4['1_total_kills'] = 0
    df_4['2_total_kills'] = 0
#     print(df_4)
    def addHeroInfo(df1,df2,column):
            res = df1.merge(df2,left_on=column,right_on='name',how='left')\
                    .rename(columns={'kills':column+'_kills','deaths':column+'_deaths','assists':column+'_assists',\
                            'KDA':column+'_KDA','dmgtoturrets':column+'_dmgtoturrets','visionscore':column+'_visionscore'})
            res[column[0]+'_total_kills'] += res[column+'_kills']
            return res
        
    for i in ('1 - MID', '1 - TOP', '1 - DUO_SUPPORT', '1 - DUO_CARRY', '1 - JUNGLE',
            '2 - MID', '2 - TOP', '2 - DUO_SUPPORT', '2 - DUO_CARRY', '2 - JUNGLE'):
        df_4 = addHeroInfo(df_4,dfcht,i)
    
    
    return df_4

# %%
feature_hero = extracting(df,df_3)

# %%
feature_hero
# Out:
#         matchid 1 - DUO_CARRY 1 - DUO_SUPPORT  1 - JUNGLE       1 - MID  \
# 0            10        Draven            Nami     Warwick        Viktor
# 1            11    Cassiopeia           Ziggs     Evelynn         Yasuo
# 2            12        Draven           Janna       Amumu           Lux
# 3            14       Caitlyn             Zac      Wukong       Orianna
# 4            15  Miss Fortune          Thresh     Warwick          Ahri
# 5            16        Lucian           Taric   Master Yi       Karthus
# 6            17          Jinx          Thresh   Master Yi        Lucian
# 7            18          Ashe          Zilean     Warwick           Lux
# 8            19        KogMaw           Janna     Sejuani         Akali
# 9            21        Draven           Janna      Gragas      Kassadin
# 10           22      Tristana         Alistar     Warwick        Anivia
# 11           23       Caitlyn            Bard     Warwick          Fizz
# 12           24         Vayne            Bard     Warwick        Viktor
# 13           25       Caitlyn            Nami      KhaZix        Ezreal
# 14           26  Miss Fortune           Leona      Graves           Lux
# 15           27         Vayne           Leona     Sejuani       Orianna
# 16           28        Draven      Blitzcrank      Graves      Vladimir
# 17           29         Xayah            Bard     Warwick         Akali
# 18           30          Jinx           Braum     Warwick           Lux
# 19           31         Xayah           Rakan     Sejuani  Twisted Fate
# 20           32       Caitlyn           Janna     Lee Sin      Katarina
# 21           33          Jhin           Braum      KhaZix       Orianna
# 22           34        Lucian         Alistar     Warwick           Zed
# 23           35  Miss Fortune         Morgana     Warwick         Galio
# 24           36       Caitlyn          Thresh        Fizz         Annie
# 25           37          Jinx         Morgana     Lee Sin           Zed
# 26           40       Caitlyn            Nami        Olaf           Lux
# 27           41          Jinx           Galio      Graves       Orianna
# 28           42          Jinx           Karma    Xin Zhao          Ahri
# 29           43        Ezreal            Sona     Sejuani          Ahri
# ...         ...           ...             ...         ...           ...
# 148604   187554      Tristana           Janna     Lee Sin          Fizz
# 21              Kled         Teemo         Morgana    Warwick           Zed
# 22              Ekko         Varus          Thresh    Evelynn         Ziggs
# 23         Gangplank        Lucian           Braum       Olaf          Fizz
# 24             Garen        Lucian           Taric    Warwick      Kassadin
# 25             Yasuo        Ezreal            Sona     KhaZix       ChoGath
# 26             Fiora         Jayce          Thresh    Warwick  Heimerdinger
# 27          Malphite        Lucian           Leona      Elise          Ahri
# 28             Riven         Sivir           Rakan         Vi           Lux
# 29            Singed  Miss Fortune      Blitzcrank   Volibear      Kassadin
# ...              ...           ...             ...        ...           ...
# 148604      Malphite         Vayne           Brand  Master Yi        Anivia
# 148605        Darius          Jinx            Nami     RekSai        Viktor
# 148606         Yasuo      Tristana            Shen    Lee Sin           Lux
# 148607      Pantheon      Tristana           Karma    Evelynn       Morgana
# 148608     Gangplank         Varus            Nami     Wukong      Katarina
# 148609         Nasus  Miss Fortune          Thresh    Kindred          Ahri
# 148610         Garen  Miss Fortune         Alistar    Nidalee         Jayce
# 148611         Nasus         Corki         Alistar     Rammus      Malzahar
# 148612      Renekton          Jinx           Janna        Zac     Lissandra
# 148613           Jax      Tristana            Shen    Nidalee       Orianna
# 148614         Fiora         Vayne           Janna        Zac       LeBlanc
# 148615       Sejuani        Lucian            Sona    Shyvana          Fizz
# 148616        Darius         Vayne           Janna     RekSai     Lissandra
# 148617      Malphite      Tristana           Leona    ChoGath          Ahri
# 148618          Fizz        Ezreal           Janna    Lee Sin      Kassadin
# 148619     Jarvan IV        Lucian      Blitzcrank    Kindred       Orianna
# 148620      Malphite         Vayne         Morgana    Lee Sin          Ryze
# 148621          Gnar         Vayne          Thresh    Trundle           Zed
# 148622          Shen          Jinx          Thresh     KhaZix           Zed
# 148623         Poppy      Tristana          Thresh     Rengar       LeBlanc
# 148624          Ryze      Tristana           Leona   Xin Zhao          Azir
# 148625       ChoGath          Jinx          Thresh      Diana           Lux
# 148626      Volibear        Ezreal           Leona    Lee Sin         Yasuo
# 148627      Malphite      Tristana          Thresh     Rammus      Katarina
# 148628      Renekton          Ashe             Lux    Lee Sin          Ahri
# 148629      Malphite      Tristana           Braum  Master Yi           Lux
# 148630         Nasus         Vayne           Janna     RekSai        Veigar
# 148631        Rumble        Lucian           Braum      Shaco           Zed
# 148632        Darius          Ashe           Janna   Volibear       LeBlanc
# 148633      Malphite          Jinx      Blitzcrank      Riven         Annie
#
#         ... 2 - DUO_CARRY_assists  2 - DUO_CARRY_dmgtoturrets  \
# 0       ...              7.607522                 4160.297148
# 1       ...              7.443961                 3807.652602
# 2       ...              7.293329                 3227.032069
# 3       ...              7.126743                 3528.743616
# 4       ...              7.969125                11335.219468
# 5       ...              7.293329                 3227.032069
# 6       ...              7.443961                 3807.652602
# 7       ...              7.443961                 3807.652602
# 8       ...              7.126743                 3528.743616
# 9       ...              7.215515                 4109.219511
# 10      ...              7.443961                 3807.652602
# 11      ...              7.126743                 3528.743616
# 12      ...              7.293329                 3227.032069
# 13      ...              5.956860                 3201.373630
# 14      ...              6.464966                 4058.536677
# 15      ...              6.511253                 4310.190435
# 16      ...              7.293329                 3227.032069
# 17      ...              8.435883                 3902.673146
# 18      ...              7.215515                 4109.219511
# 19      ...              6.760651                 3290.051563
# 20      ...              7.293329                 3227.032069
# 21      ...              6.308570                 3202.547291
# 22      ...              8.001917                 3621.285075
# 23      ...              7.126743                 3528.743616
# 24      ...              7.126743                 3528.743616
# 25      ...              8.041867                 2549.857319
# 26      ...              6.747142                 3549.654943
# 27      ...              7.126743                 3528.743616
# 28      ...              8.672029                 3242.732261
# 29      ...              8.435883                 3902.673146
# ...     ...                   ...                         ...
# 148604  ...              5.956860                 3201.373630
# 148605  ...              7.607522                 4160.297148
# 148606  ...              6.511253                 4310.190435
# 148607  ...              6.511253                 4310.190435
# 148608  ...              8.001917                 3621.285075
# 148609  ...              8.435883                 3902.673146
# 148610  ...              8.435883                 3902.673146
# 148611  ...              7.901920                 1709.328490
# 148612  ...              7.607522                 4160.297148
# 148613  ...              6.511253                 4310.190435
# 148614  ...              5.956860                 3201.373630
# 148615  ...              7.126743                 3528.743616
# 148616  ...              5.956860                 3201.373630
# 148617  ...              6.511253                 4310.190435
# 148618  ...              8.041867                 2549.857319
# 148619  ...              7.126743                 3528.743616
# 148620  ...              5.956860                 3201.373630
# 148621  ...              5.956860                 3201.373630
# 148622  ...              7.607522                 4160.297148
# 148623  ...              6.511253                 4310.190435
# 148624  ...              6.511253                 4310.190435
# 148625  ...              7.607522                 4160.297148
# 148626  ...              8.041867                 2549.857319
# 148627  ...              6.511253                 4310.190435
# 148628  ...              8.744272                 3502.367152
# 148629  ...              6.511253                 4310.190435
# 148630  ...              5.956860                 3201.373630
# 148631  ...              7.126743                 3528.743616
# 148632  ...              8.744272                 3502.367152
# 148633  ...              7.607522                 4160.297148
#
#         2 - DUO_CARRY_visionscore  2 - DUO_CARRY_KDA  2 - JUNGLE_kills  \
# 0                        9.347523           2.437049          4.790698
# 1                       10.467949           2.403311          7.167596
# 2                       10.975155           2.556030          6.427994
# 3                       10.461909           2.588697          7.167596
# 4                       11.354221           2.431721          6.660166
# 5                       10.975155           2.556030          7.167596
# 6                       10.467949           2.403311          7.167596
# 7                       10.467949           2.403311          6.660166
# 8                       10.461909           2.588697          7.167596
# 9                       10.641233           2.353112          7.167596
# 10                      10.467949           2.403311          4.689442
# 11                      10.461909           2.588697          3.526105
# 12                      10.975155           2.556030          7.885168
# 13                       9.954429           2.130511          7.167596
# 14                       9.660985           2.196565          7.167596
# 15                       9.739717           2.471919          2.709681
# 16                      10.975155           2.556030          6.660166
# 17                      11.684668           2.566865          2.639934
# 18                      10.641233           2.353112          6.660166
# 19                       8.978790           2.240990          7.167596
# 20                      10.975155           2.556030          7.167596
# 21                      12.245515           1.816506          7.167596
# 22                      10.455788           2.454740          8.232377
# 23                      10.461909           2.588697          6.299602
# 24                      10.461909           2.588697          7.167596
# 25                       8.761148           2.705592          7.885168
# 26                      11.846250           2.291037          7.167596
# 27                      10.461909           2.588697          6.532351
# 28                       9.703307           2.593533          6.427994
# 29                      11.684668           2.566865          5.958966
# ...                           ...                ...               ...
# 148616           5.240957            9.291132              1016.393232
# 148617           5.489940            6.517799              1536.669132
# 148618           6.163571            8.526725              1321.807970
# 148619           6.943795            7.619766              1579.357601
# 148620           6.163571            8.526725              1321.807970
# 148621           5.456278            7.964902              2535.071104
# 148622           5.710046            6.405910              1280.947145
# 148623           6.622458            6.381335              1172.032473
# 148624           6.814457            6.567947              2583.002561
# 148625           6.709408            6.539412              2537.766073
# 148626           6.163571            8.526725              1321.807970
# 148627           5.857275           10.772884              1058.254554
# 148628           6.163571            8.526725              1321.807970
# 148629           7.100530            5.032185              2570.170395
# 148630           5.240957            9.291132              1016.393232
# 148631           5.787387            7.521781              1822.186116
# 148632           5.600332            8.658918              1550.621679
# 148633           6.148474            5.270568              2481.588015
#
#         2 - JUNGLE_visionscore  2 - JUNGLE_KDA
# 0                    12.152326        2.790668
# 1                    11.762421        2.408164
# 2                    12.077257        2.352293
# 3                    11.762421        2.408164
# 4                    21.462089        2.463976
# 5                    11.762421        2.408164
# 6                    11.762421        2.408164
# 7                    21.462089        2.463976
# 8                    11.762421        2.408164
# 9                    11.762421        2.408164
# 10                   17.028147        3.104571
# 11                   20.065146        2.880586
# 12                   14.847807        2.502796
# 13                   11.762421        2.408164
# 14                   11.762421        2.408164
# 15                   15.806774        2.579354
# 16                   21.462089        2.463976
# 17                   15.520762        3.834547
# 18                   21.462089        2.463976
# 19                   11.762421        2.408164
# 20                   11.762421        2.408164
# 21                   11.762421        2.408164
# 22                   12.775239        2.677725
# 23                   11.693426        2.169535
# 24                   11.762421        2.408164
# 25                   14.847807        2.502796
# 26                   11.762421        2.408164
# 27                   14.906777        2.362714
# 28                   12.077257        2.352293
# 29                   11.789848        2.610182
# ...                        ...             ...
# 148604               12.535080        1.964816
# 148605               10.456826        2.735500
# 148606               21.462089        2.463976
# 148607               12.775239        2.677725
# 148608               10.558514        2.389706
# 148609               14.055074        2.054053
# 148610               13.688496        2.341343
# 148611               13.626931        2.574302
# 148612               13.160264        3.473549
# 148613               13.688496        2.341343
# 148614               13.160264        3.473549
# 148615               11.979894        2.374135
# 148616               10.456826        2.735500
# 148617               10.657266        2.328248
# 148618               21.462089        2.463976
# 148619               14.055074        2.054053
# 148620               21.462089        2.463976
# 148621               11.363994        2.365330
# 148622               14.847807        2.502796
# 148623               11.079363        2.024059
# 148624               12.396778        1.986144
# 148625               10.400654        2.127497
# 148626               21.462089        2.463976
# 148627               13.626931        2.574302
# 148628               21.462089        2.463976
# 148629               12.535080        1.964816
# 148630               10.456826        2.735500
# 148631               13.022258        2.501300
# 148632               11.789848        2.610182
# 148633               11.488995        2.032720
#
# [148634 rows x 74 columns]

# %% [markdown]
# ### 构造伤害特征

# %%
def feature_dcdd(df,df_3,champs):
    champs['mid_dc']  = 1 
    champs['ad_dc'] = 1
    champs['top_dd'] = 1

    
    #按英雄计算每个英雄在MID/AD/TOP位置的伤害转换比/不死承伤
    #dc = 伤害转换比
    #dd = 不死承伤
    for i in range(138):
        idx = champs.loc[i,'id']
        df2 = df.loc[(df["championid"] == idx)&(df["adjposition"] == 'MID')]#从总表中找出该英雄在中单位的所有比赛
        df2['goldspent']=df2['goldspent'].apply(lambda x: df2['goldspent'].mean() if x == 0 else x)#为空则用平均值替代
        df3 = df2.apply(lambda x: x['totdmgtochamp'] / x['goldspent'], axis=1).mean()
        champs.loc[champs['id'] == idx,'mid_dc'] = df3
        
        df4 = df.loc[(df["championid"] == idx)&(df["adjposition"] == 'DUO_CARRY')]
        df4['goldspent']=df4['goldspent'].apply(lambda x: df4['goldspent'].mean() if x == 0 else x)
        df5 = df4.apply(lambda x: x['totdmgtochamp'] / x['goldspent'], axis=1).mean()
        champs.loc[champs['id'] == idx,'ad_dc'] = df5
        
        df6 = df.loc[(df["championid"] == idx)&(df["adjposition"] == 'TOP')]
        df6['deaths']=df6['deaths'].apply(lambda x: 1 if x == 0 else x)
        df7 = df6.apply(lambda x: x['totdmgtaken'] / x['deaths'], axis=1).mean()
        champs.loc[champs['id'] == idx,'top_dd'] = df7
        
   #合并到总表
   #1_ad_dc
    champs = champs.rename(columns = {"name":"1 - DUO_CARRY"})
    test1 = pd.merge(df_3,champs,how="left")
    test1.drop("id",axis = 1,inplace = True)
    test1.drop('mid_dc',axis = 1,inplace = True)
    test1.drop('top_dd',axis = 1,inplace = True)
    test1 = test1.rename(columns = {"ad_dc":"1_ad_dc"})
    
    
    #合并到总表
    #2_ad_dc
    champs = champs.rename(columns = {"1 - DUO_CARRY":"2 - DUO_CARRY"})
    test1 = pd.merge(test1,champs,how="left")
    test1.drop('id',axis = 1,inplace = True)
    test1.drop('mid_dc',axis = 1,inplace = True)
    test1.drop('top_dd',axis = 1,inplace = True)
    test1 = test1.rename(columns = {"ad_dc":"2_ad_dc"})
    
    
    #合并到总表
    #1_mid_dc
    champs = champs.rename(columns = {"2 - DUO_CARRY":"1 - MID"})
    test1 = pd.merge(test1,champs,how="left")
    test1.drop('id',axis = 1,inplace = True)
    test1.drop('ad_dc',axis = 1,inplace = True)
    test1.drop('top_dd',axis = 1,inplace = True)
    test1 = test1.rename(columns = {"mid_dc":"1_mid_dc"})
    
    #合并到总表
    #2_mid_dc
    champs = champs.rename(columns = {"1 - MID":"2 - MID"})
    test1 = pd.merge(test1,champs,how="left")
    test1.drop('id',axis = 1,inplace = True)
    test1.drop('ad_dc',axis = 1,inplace = True)
    test1.drop('top_dd',axis = 1,inplace = True)
    test1 = test1.rename(columns = {"mid_dc":"2_mid_dc"})
    
    
    #合并到总表
    #1_top_dd
    champs = champs.rename(columns = {"2 - MID":"1 - TOP"})
    test1 = pd.merge(test1,champs,how="left")
    test1.drop('id',axis = 1,inplace = True)
    test1.drop('ad_dc',axis = 1,inplace = True)
    test1.drop('mid_dc',axis = 1,inplace = True)
    test1 = test1.rename(columns = {"top_dd":"1_top_dd"})
    
    #合并到总表
    #2_top_dd
    champs = champs.rename(columns = {"1 - TOP":"2 - TOP"})
    test1 = pd.merge(test1,champs,how="left")
    test1.drop('id',axis = 1,inplace = True)
    test1.drop('ad_dc',axis = 1,inplace = True)
    test1.drop('mid_dc',axis = 1,inplace = True)
    test1 = test1.rename(columns = {"top_dd":"2_top_dd"})
   
    return test1

# %%
feature_hero_dcdd = feature_dcdd(df,feature_hero,champs)
# Out:
# D:\DevTools\anaconda\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# D:\DevTools\anaconda\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# D:\DevTools\anaconda\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
feature_hero_dcdd
# Out:
#         matchid 1 - DUO_CARRY 1 - DUO_SUPPORT  1 - JUNGLE       1 - MID  \
# 0            10        Draven            Nami     Warwick        Viktor
# 1            11    Cassiopeia           Ziggs     Evelynn         Yasuo
# 2            12        Draven           Janna       Amumu           Lux
# 3            14       Caitlyn             Zac      Wukong       Orianna
# 4            15  Miss Fortune          Thresh     Warwick          Ahri
# 5            16        Lucian           Taric   Master Yi       Karthus
# 6            17          Jinx          Thresh   Master Yi        Lucian
# 7            18          Ashe          Zilean     Warwick           Lux
# 8            19        KogMaw           Janna     Sejuani         Akali
# 9            21        Draven           Janna      Gragas      Kassadin
# 10           22      Tristana         Alistar     Warwick        Anivia
# 11           23       Caitlyn            Bard     Warwick          Fizz
# 12           24         Vayne            Bard     Warwick        Viktor
# 13           25       Caitlyn            Nami      KhaZix        Ezreal
# 14           26  Miss Fortune           Leona      Graves           Lux
# 15           27         Vayne           Leona     Sejuani       Orianna
# 16           28        Draven      Blitzcrank      Graves      Vladimir
# 17           29         Xayah            Bard     Warwick         Akali
# 18           30          Jinx           Braum     Warwick           Lux
# 19           31         Xayah           Rakan     Sejuani  Twisted Fate
# 20           32       Caitlyn           Janna     Lee Sin      Katarina
# 21           33          Jhin           Braum      KhaZix       Orianna
# 22           34        Lucian         Alistar     Warwick           Zed
# 23           35  Miss Fortune         Morgana     Warwick         Galio
# 24           36       Caitlyn          Thresh        Fizz         Annie
# 25           37          Jinx         Morgana     Lee Sin           Zed
# 26           40       Caitlyn            Nami        Olaf           Lux
# 27           41          Jinx           Galio      Graves       Orianna
# 28           42          Jinx           Karma    Xin Zhao          Ahri
# 29           43        Ezreal            Sona     Sejuani          Ahri
# ...         ...           ...             ...         ...           ...
# 148604   187554      Tristana           Janna     Lee Sin          Fizz
# 148605   187555         Corki           Janna        Udyr         Brand
# 148606   187556        Lucian           Brand       Amumu        Syndra
# 148607   187557         Sivir          Thresh   Master Yi         Annie
# 148608   187558      Tristana        Nautilus     Lee Sin          Ahri
# 148609   187559      Tristana           Janna   Jarvan IV         Brand
# 148610   187560      Tristana           Braum      Rengar  Heimerdinger
# 148611   187561         Sivir           Janna   Master Yi        Veigar
# 148612   187562       Caitlyn         Morgana       Diana      Katarina
# 148613   187563          Jinx        Malphite       Shaco           Zed
# 148614   187565        Lucian          Thresh  Tahm Kench        Veigar
# 148615   187566      Tristana      Blitzcrank        Udyr          Ahri
# 148616   187567        Ezreal           Poppy        Ekko           Zed
# 148617   187568         Vayne         Alistar     Trundle           Zed
# 148618   187569        Lucian      Blitzcrank          Vi       LeBlanc
# 148619   187570      Tristana         Morgana        Fizz          Ahri
# 148620   187572        Lucian           Braum        Udyr       LeBlanc
# 148621   187574  Miss Fortune           Janna          Vi      Malzahar
# 148611         Nasus         Corki         Alistar     Rammus      Malzahar
# 148612      Renekton          Jinx           Janna        Zac     Lissandra
# 148613           Jax      Tristana            Shen    Nidalee       Orianna
# 148614         Fiora         Vayne           Janna        Zac       LeBlanc
# 148615       Sejuani        Lucian            Sona    Shyvana          Fizz
# 148616        Darius         Vayne           Janna     RekSai     Lissandra
# 148617      Malphite      Tristana           Leona    ChoGath          Ahri
# 148618          Fizz        Ezreal           Janna    Lee Sin      Kassadin
# 148619     Jarvan IV        Lucian      Blitzcrank    Kindred       Orianna
# 148620      Malphite         Vayne         Morgana    Lee Sin          Ryze
# 148621          Gnar         Vayne          Thresh    Trundle           Zed
# 148622          Shen          Jinx          Thresh     KhaZix           Zed
# 148623         Poppy      Tristana          Thresh     Rengar       LeBlanc
# 148624          Ryze      Tristana           Leona   Xin Zhao          Azir
# 148625       ChoGath          Jinx          Thresh      Diana           Lux
# 148626      Volibear        Ezreal           Leona    Lee Sin         Yasuo
# 148627      Malphite      Tristana          Thresh     Rammus      Katarina
# 148628      Renekton          Ashe             Lux    Lee Sin          Ahri
# 148629      Malphite      Tristana           Braum  Master Yi           Lux
# 148630         Nasus         Vayne           Janna     RekSai        Veigar
# 148631        Rumble        Lucian           Braum      Shaco           Zed
# 148632        Darius          Ashe           Janna   Volibear       LeBlanc
# 148633      Malphite          Jinx      Blitzcrank      Riven         Annie
#
#         ... 2 - JUNGLE_assists  2 - JUNGLE_dmgtoturrets  \
# 0       ...           9.222674              1273.091279
# 1       ...           7.789013              1274.079582
# 2       ...           7.930923              1618.634518
# 3       ...           7.789013              1274.079582
# 4       ...           8.526725              1321.807970
# 5       ...           7.789013              1274.079582
# 6       ...           7.789013              1274.079582
# 7       ...           8.526725              1321.807970
# 8       ...           7.789013              1274.079582
# 9       ...           7.789013              1274.079582
# 10      ...          11.386628               815.739249
# 11      ...          10.815851              1152.911571
# 12      ...           6.405910              1280.947145
# 13      ...           7.789013              1274.079582
# 14      ...           7.789013              1274.079582
# 15      ...          11.271747               735.801386
# 16      ...           8.526725              1321.807970
# 17      ...          13.299505              1320.596462
# 18      ...           8.526725              1321.807970
# 19      ...           7.789013              1274.079582
# 20      ...           7.789013              1274.079582
# 21      ...           7.789013              1274.079582
# 22      ...           8.366391              1106.622590
# 23      ...           6.884861              2311.133665
# 24      ...           7.789013              1274.079582
# 25      ...           6.405910              1280.947145
# 26      ...           7.789013              1274.079582
# 27      ...           7.769453              1639.626852
# 28      ...           7.930923              1618.634518
# 29      ...           8.658918              1550.621679
# ...     ...                ...                      ...
# 148604  ...           5.032185              2570.170395
# 148605  ...           9.291132              1016.393232
# 148606  ...           8.526725              1321.807970
# 148607  ...           8.366391              1106.622590
# 148608  ...           7.146943              2317.096318
# 148609  ...           7.619766              1579.357601
# 148610  ...           7.340487              1546.468363
# 148611  ...          10.772884              1058.254554
# 148612  ...          11.517887               625.622455
# 148613  ...           7.340487              1546.468363
# 148614  ...          11.517887               625.622455
# 148615  ...           7.010400              1923.367460
# 148616  ...           9.291132              1016.393232
# 148614  1.846180  6063.924507  4713.623416
# 148615  1.786477  5951.884977  5555.978828
# 148616  1.788633  6513.916470  7487.953516
# 148617  2.012985  5776.655633  5555.978828
# 148618  1.901935  5034.453897  4713.623416
# 148619  1.833891  5555.978828  6858.990947
# 148620  1.757569  5776.655633  7487.953516
# 148621  1.819516  6070.471444  5920.044581
# 148622  1.819516  7290.249079  4713.623416
# 148623  1.846180  6603.712269  8182.162971
# 148624  1.969674  4314.478015  7487.953516
# 148625  2.089822  8182.162971  6088.164838
# 148626  1.693690  7596.065474  7633.987306
# 148627  1.947412  5776.655633  8497.489915
# 148628  2.012985  7397.441372  6858.990947
# 148629  2.089822  5776.655633  4713.623416
# 148630  1.908221  7633.987306  3844.766707
# 148631  1.819516  4424.126183  6070.471444
# 148632  1.846180  6513.916470  7633.987306
# 148633  2.005302  5776.655633  5837.157768
#
# [148634 rows x 80 columns]

# %% [markdown]
# ### 构造对手特征

# %%
df_5 = df.sort_values(['matchid','adjposition'], ascending = [1,1])

df_5['shift 1'] = df_5['name'].shift()
df_5['shift -1'] = df_5['name'].shift(-1)

def get_rival(x):
    if x['player'] <= 5:
        name_return = x['name'] + ' vs ' + x['shift -1']
    else:
        name_return = x['name'] + ' vs ' + x['shift 1']
    return name_return

df_5['match up'] = df_5.apply(get_rival, axis = 1)

# %%
df_rival = df_5.groupby(['adjposition', 'match up']).agg({'win': 'sum', 'match up': 'count'})
df_rival.columns = ['win matches', 'total matches']
df_rival['total matches'] = df_rival['total matches']
df_rival['win rate'] = df_rival['win matches'] /  df_rival['total matches']  * 100
df_rival['dominant score'] = df_rival['win rate'] - 50
df_rival['dominant score (ND)'] = abs(df_rival['dominant score'])
df_rival = df_rival[df_rival['total matches'] > df_rival['total matches'].sum()*0.0001]               
df_rival = df_rival.reset_index()

# %%
df_rival.head(5)
# Out:
#   adjposition         match up  win matches  total matches   win rate  \
# 0   DUO_CARRY  Ashe vs Caitlyn       1836.0           3625  50.648276
# 1   DUO_CARRY   Ashe vs Draven        491.0           1029  47.716229
# 2   DUO_CARRY   Ashe vs Ezreal        757.0           1425  53.122807
# 3   DUO_CARRY     Ashe vs Jhin        332.0            635  52.283465
# 4   DUO_CARRY     Ashe vs Jinx        669.0           1368  48.903509
#
#    dominant score  dominant score (ND)
# 0        0.648276             0.648276
# 1       -2.283771             2.283771
# 2        3.122807             3.122807
# 3        2.283465             2.283465
# 4       -1.096491             1.096491

# %% [markdown]
# ### 合并对手特征到df_3

# %%
feature_hero_dcdd_rival = feature_hero_dcdd.copy()
feature_hero_dcdd_rival ['carry_vs'] = feature_hero_dcdd_rival ['1 - DUO_CARRY'] + ' vs ' + feature_hero_dcdd_rival['2 - DUO_CARRY']
feature_hero_dcdd_rival['support_vs'] = feature_hero_dcdd_rival['1 - DUO_SUPPORT'] + ' vs ' + feature_hero_dcdd_rival['2 - DUO_SUPPORT']
feature_hero_dcdd_rival['jungle_vs'] = feature_hero_dcdd_rival['1 - JUNGLE'] + ' vs ' + feature_hero_dcdd_rival['2 - JUNGLE']
feature_hero_dcdd_rival['mid_vs'] = feature_hero_dcdd_rival['1 - MID'] + ' vs ' + feature_hero_dcdd_rival['2 - MID']
feature_hero_dcdd_rival['top_vs'] = feature_hero_dcdd_rival['1 - TOP'] + ' vs ' + feature_hero_dcdd_rival['2 - TOP']

# %%
feature_hero_dcdd_rival =feature_hero_dcdd_rival\
           .merge(df_rival[df_rival['adjposition']=='DUO_CARRY'][['match up','dominant score']]\
                  .rename(columns={'dominant score':'carry_vs_score'}),\
                  left_on='carry_vs',right_on='match up',how='left').drop(['match up'],axis=1)\
           .merge(df_rival[df_rival['adjposition']=='DUO_SUPPORT'][['match up','dominant score']]\
                  .rename(columns={'dominant score':'support_vs_score'}),\
                  left_on='support_vs',right_on='match up',how='left').drop(['match up'],axis=1)\
           .merge(df_rival[df_rival['adjposition']=='JUNGLE'][['match up','dominant score']]\
                  .rename(columns={'dominant score':'jungle_vs_score'}),\
                  left_on='jungle_vs',right_on='match up',how='left').drop(['match up'],axis=1)\
           .merge(df_rival[df_rival['adjposition']=='MID'][['match up','dominant score']]\
                  .rename(columns={'dominant score':'mid_vs_score'}),\
                  left_on='mid_vs',right_on='match up',how='left').drop(['match up'],axis=1)\
           .merge(df_rival[df_rival['adjposition']=='TOP'][['match up','dominant score']]\
                  .rename(columns={'dominant score':'top_vs_score'}),\
                  left_on='top_vs',right_on='match up',how='left').drop(['match up'],axis=1)

feature_hero_dcdd_rival.head()
# Out:
#    matchid 1 - DUO_CARRY 1 - DUO_SUPPORT 1 - JUNGLE  1 - MID       1 - TOP  \
# 0       10        Draven            Nami    Warwick   Viktor         Fiora
# 1       11    Cassiopeia           Ziggs    Evelynn    Yasuo  Twisted Fate
# 2       12        Draven           Janna      Amumu      Lux         Vayne
# 3       14       Caitlyn             Zac     Wukong  Orianna         Urgot
# 4       15  Miss Fortune          Thresh    Warwick     Ahri         Garen
#
#   2 - DUO_CARRY 2 - DUO_SUPPORT 2 - JUNGLE  2 - MID  ...  \
# 0          Jinx          VelKoz    Skarner     Ahri  ...
# 1       Caitlyn           Karma    Warwick   Syndra  ...
# 2        Twitch            Nami         Vi     Ahri  ...
# 3        Lucian           Karma    Warwick  Morgana  ...
# 4         Ziggs            Nami    Lee Sin    Yasuo  ...
#
#                 carry_vs      support_vs           jungle_vs  \
# 0         Draven vs Jinx  Nami vs VelKoz  Warwick vs Skarner
# 1  Cassiopeia vs Caitlyn  Ziggs vs Karma  Evelynn vs Warwick
# 2       Draven vs Twitch   Janna vs Nami         Amumu vs Vi
# 3      Caitlyn vs Lucian    Zac vs Karma   Wukong vs Warwick
# 4  Miss Fortune vs Ziggs  Thresh vs Nami  Warwick vs Lee Sin
#
#                mid_vs                  top_vs  carry_vs_score  \
# 0      Viktor vs Ahri          Fiora vs Galio       -0.223015
# 1     Yasuo vs Syndra  Twisted Fate vs Wukong             NaN
# 2         Lux vs Ahri        Vayne vs Caitlyn        2.918288
# 3  Orianna vs Morgana         Urgot vs Darius        0.246978
# 4       Ahri vs Yasuo     Garen vs Tryndamere             NaN
#
#    support_vs_score  jungle_vs_score  mid_vs_score  top_vs_score
# 0         -3.987730              NaN     -5.040000      1.256281
# 1               NaN        -4.255319      4.633205           NaN
# 2          2.587992         0.352941     -1.333010           NaN
# 3               NaN              NaN      1.054852           NaN
# 4          1.661356         4.265949      1.525719     -0.588235
#
# [5 rows x 90 columns]

# %% [markdown]
# ### 构造队友合作特征

# %%
df_8 = df.sort_values(['matchid','team_role'], ascending = [1,1])
df_8['shift -1'] = df_8['name'].shift(-1)
df_8['match up'] = df_8['name'] + ' & ' + df_8['shift -1']

# %%
df_teammates = (df_8[df_8['adjposition']=='DUO_CARRY']).append(df_8[df_8['adjposition']=='JUNGLE'])
df_teammates = df_teammates.groupby(['adjposition', 'match up']).agg({'win': 'sum', 'match up': 'count'})
df_teammates.columns = ['win matches', 'total matches']
df_teammates['total matches'] = df_teammates['total matches']
df_teammates['win rate'] = df_teammates['win matches'] /  df_teammates['total matches']  * 100
df_teammates['dominant score'] = df_teammates['win rate'] - 50
df_teammates['dominant score (ND)'] = abs(df_teammates['dominant score'])
df_teammates = df_teammates[df_teammates['total matches'] > df_teammates['total matches'].sum()*0.0001]                
df_teammates = df_teammates.reset_index()

# %% [markdown]
# ### 合并队友合作特征到df_3

# %%
feature_hero_dcdd_riva_teama = feature_hero_dcdd_rival.copy()
feature_hero_dcdd_riva_teama['teammates_jungle_mid'] = feature_hero_dcdd_riva_teama['1 - JUNGLE'] + ' & '\
                                                        + feature_hero_dcdd_riva_teama['1 - MID']
feature_hero_dcdd_riva_teama['teammates_carry_sup'] = feature_hero_dcdd_riva_teama['1 - DUO_CARRY'] + ' & '\
                                                        + feature_hero_dcdd_riva_teama['1 - DUO_SUPPORT']

# %%
feature_hero_dcdd_riva_teama = feature_hero_dcdd_riva_teama.merge(df_teammates[df_teammates['adjposition']=='DUO_CARRY'][['match up','dominant score']]\
                  .rename(columns={'dominant score':'teammates_carry_sup_score'}),\
                  left_on='teammates_carry_sup',right_on='match up',how='left').drop(['match up'],axis=1)\
           .merge(df_teammates[df_teammates['adjposition']=='JUNGLE'][['match up','dominant score']]\
                  .rename(columns={'dominant score':'teammates_jungle_mid_score'}),\
                  left_on='teammates_jungle_mid',right_on='match up',how='left').drop(['match up'],axis=1)

feature_hero_dcdd_riva_teama.head()
# Out:
#    matchid 1 - DUO_CARRY 1 - DUO_SUPPORT 1 - JUNGLE  1 - MID       1 - TOP  \
# 0       10        Draven            Nami    Warwick   Viktor         Fiora
# 1       11    Cassiopeia           Ziggs    Evelynn    Yasuo  Twisted Fate
# 2       12        Draven           Janna      Amumu      Lux         Vayne
# 3       14       Caitlyn             Zac     Wukong  Orianna         Urgot
# 4       15  Miss Fortune          Thresh    Warwick     Ahri         Garen
#
#   2 - DUO_CARRY 2 - DUO_SUPPORT 2 - JUNGLE  2 - MID  ...  \
# 0          Jinx          VelKoz    Skarner     Ahri  ...
# 1       Caitlyn           Karma    Warwick   Syndra  ...
# 2        Twitch            Nami         Vi     Ahri  ...
# 3        Lucian           Karma    Warwick  Morgana  ...
# 4         Ziggs            Nami    Lee Sin    Yasuo  ...
#
#                    top_vs  carry_vs_score  support_vs_score  jungle_vs_score  \
# 0          Fiora vs Galio       -0.223015         -3.987730              NaN
# 1  Twisted Fate vs Wukong             NaN               NaN        -4.255319
# 2        Vayne vs Caitlyn        2.918288          2.587992         0.352941
# 3         Urgot vs Darius        0.246978               NaN              NaN
# 4     Garen vs Tryndamere             NaN          1.661356         4.265949
#
#    mid_vs_score  top_vs_score  teammates_jungle_mid    teammates_carry_sup  \
# 0     -5.040000      1.256281      Warwick & Viktor          Draven & Nami
# 1      4.633205           NaN       Evelynn & Yasuo     Cassiopeia & Ziggs
# 2     -1.333010           NaN           Amumu & Lux         Draven & Janna
# 3      1.054852           NaN      Wukong & Orianna          Caitlyn & Zac
# 4      1.525719     -0.588235        Warwick & Ahri  Miss Fortune & Thresh
#
#    teammates_carry_sup_score  teammates_jungle_mid_score
# 0                   1.720183                   -3.488372
# 1                        NaN                   -1.592357
# 2                   4.726688                    5.032468
# 3                        NaN                   -2.941176
# 4                   2.794562                    2.766532
#
# [5 rows x 94 columns]

# %%
feature_hero_dcdd_riva_teama.shape
# Out:
# (148634, 94)

# %%
nullrows = feature_hero_dcdd_riva_teama.isnull().any(1)

# %%
feature_hero_dcdd_riva_teama[nullrows]
# Out:
#         matchid 1 - DUO_CARRY 1 - DUO_SUPPORT  1 - JUNGLE       1 - MID  \
# 0            10        Draven            Nami     Warwick        Viktor
# 1            11    Cassiopeia           Ziggs     Evelynn         Yasuo
# 2            12        Draven           Janna       Amumu           Lux
# 3            14       Caitlyn             Zac      Wukong       Orianna
# 4            15  Miss Fortune          Thresh     Warwick          Ahri
# 5            16        Lucian           Taric   Master Yi       Karthus
# 6            17          Jinx          Thresh   Master Yi        Lucian
# 7            18          Ashe          Zilean     Warwick           Lux
# 8            19        KogMaw           Janna     Sejuani         Akali
# 10           22      Tristana         Alistar     Warwick        Anivia
# 11           23       Caitlyn            Bard     Warwick          Fizz
# 13           25       Caitlyn            Nami      KhaZix        Ezreal
# 14           26  Miss Fortune           Leona      Graves           Lux
# 15           27         Vayne           Leona     Sejuani       Orianna
# 16           28        Draven      Blitzcrank      Graves      Vladimir
# 17           29         Xayah            Bard     Warwick         Akali
# 20           32       Caitlyn           Janna     Lee Sin      Katarina
# 21           33          Jhin           Braum      KhaZix       Orianna
# 23           35  Miss Fortune         Morgana     Warwick         Galio
# 24           36       Caitlyn          Thresh        Fizz         Annie
# 25           37          Jinx         Morgana     Lee Sin           Zed
# 26           40       Caitlyn            Nami        Olaf           Lux
# 27           41          Jinx           Galio      Graves       Orianna
# 29           43        Ezreal            Sona     Sejuani          Ahri
# 30           45          Ashe           Annie   Master Yi      Vladimir
# 31           46  Miss Fortune        Nautilus     Warwick          Ahri
# 32           47        Lucian           Taric       Akali          Ekko
# 33           51         Vayne           Braum    Nocturne         Yasuo
# 34           55         Vayne            Lulu     Warwick          Ekko
# 35           57       Caitlyn            Bard     Warwick       Morgana
# ...         ...           ...             ...         ...           ...
# 25             Yasuo        Ezreal            Sona     KhaZix       ChoGath
# 26             Fiora         Jayce          Thresh    Warwick  Heimerdinger
# 27          Malphite        Lucian           Leona      Elise          Ahri
# 29            Singed  Miss Fortune      Blitzcrank   Volibear      Kassadin
# 30             Nasus        Lucian          Thresh    Warwick         Galio
# 31           Camille        Lucian           Leona    Nidalee        VelKoz
# 32            Wukong  Miss Fortune          Soraka    Warwick      Malzahar
# 33          Katarina         Xayah         Morgana     Rengar           Lux
# 34              Gnar          Jinx      Blitzcrank        Zac          Sion
# 35              Sion          Ashe          Soraka    Sejuani           Zed
# ...              ...           ...             ...        ...           ...
# 148601        Darius         Sivir        Nautilus      Diana        Anivia
# 148602      Renekton          Jinx           Janna      Elise          Ahri
# 148603         Garen        Ezreal          Thresh     Graves         Diana
# 148604      Malphite         Vayne           Brand  Master Yi        Anivia
# 148605        Darius          Jinx            Nami     RekSai        Viktor
# 148606         Yasuo      Tristana            Shen    Lee Sin           Lux
# 148607      Pantheon      Tristana           Karma    Evelynn       Morgana
# 148609         Nasus  Miss Fortune          Thresh    Kindred          Ahri
# 148610         Garen  Miss Fortune         Alistar    Nidalee         Jayce
# 148611         Nasus         Corki         Alistar     Rammus      Malzahar
# 148612      Renekton          Jinx           Janna        Zac     Lissandra
# 148613           Jax      Tristana            Shen    Nidalee       Orianna
# 148614         Fiora         Vayne           Janna        Zac       LeBlanc
# 148615       Sejuani        Lucian            Sona    Shyvana          Fizz
# 148616        Darius         Vayne           Janna     RekSai     Lissandra
# 148617      Malphite      Tristana           Leona    ChoGath          Ahri
# 148619     Jarvan IV        Lucian      Blitzcrank    Kindred       Orianna
# 148620      Malphite         Vayne         Morgana    Lee Sin          Ryze
# 148621          Gnar         Vayne          Thresh    Trundle           Zed
# 148623         Poppy      Tristana          Thresh     Rengar       LeBlanc
# 148624          Ryze      Tristana           Leona   Xin Zhao          Azir
# 148625       ChoGath          Jinx          Thresh      Diana           Lux
# 148626      Volibear        Ezreal           Leona    Lee Sin         Yasuo
# 148627      Malphite      Tristana          Thresh     Rammus      Katarina
# 148628      Renekton          Ashe             Lux    Lee Sin          Ahri
# 148629      Malphite      Tristana           Braum  Master Yi           Lux
# 148630         Nasus         Vayne           Janna     RekSai        Veigar
# 148631        Rumble        Lucian           Braum      Shaco           Zed
# 148632        Darius          Ashe           Janna   Volibear       LeBlanc
# 148633      Malphite          Jinx      Blitzcrank      Riven         Annie
#
#         ...                  top_vs  carry_vs_score  support_vs_score  \
# 0       ...          Fiora vs Galio       -0.223015         -3.987730
# 1       ...  Twisted Fate vs Wukong             NaN               NaN
# 2       ...        Vayne vs Caitlyn        2.918288          2.587992
# 3       ...         Urgot vs Darius        0.246978               NaN
# 4       ...     Garen vs Tryndamere             NaN          1.661356
# 5       ...          Yasuo vs Nasus       -2.696078          2.760736
# 6       ...        Wukong vs Darius        0.291579          2.256532
# 7       ...      Jarvan IV vs Teemo        0.648276         -1.901566
# 8       ...      Illaoi vs Renekton        2.169625          2.627570
# 10      ...       Trundle vs Darius       -0.981524          2.560647
# 11      ...        Illaoi vs Darius        0.246978          1.995163
# 13      ...      Fiora vs Gangplank        0.873033         -3.695652
# 14      ...         Trundle vs Fizz        1.661130          1.619778
# 15      ...         Talon vs Rumble       -0.934120          4.482759
# 16      ...      Master Yi vs Fiora        2.918288         -1.333872
# 17      ...  Irelia vs Heimerdinger       -3.319058         -4.482759
# 20      ...         Darius vs Yasuo       -2.224371          2.627570
# 21      ...      Kled vs Tryndamere             NaN         -1.528384
# 23      ...     Gangplank vs Kennen        1.228070          1.528384
# 24      ...      Garen vs Gangplank        0.246978         -1.990632
# 25      ...          Yasuo vs Kayle        5.475880         -5.986509
# 26      ...         Fiora vs Irelia             NaN         -1.661356
# 27      ...       Malphite vs Fiora        0.609938               NaN
# 29      ...         Singed vs Garen       -6.697009         -1.747312
# 30      ...           Nasus vs Fizz       -0.197239         -1.863354
# 31      ...       Camille vs Irelia        1.228070         -3.618421
# 32      ...    Wukong vs Tryndamere       -1.228070               NaN
# 33      ...       Katarina vs Poppy       -0.569861         -1.528384
# 34      ...           Gnar vs Nasus       -0.091408         -4.849226
# 35      ...         Sion vs ChoGath       -0.648276          0.793651
# ...     ...                     ...             ...               ...
# 148601  ...          Darius vs Gnar       -1.688312          5.448718
# 148602  ...      Renekton vs Irelia       -5.475880         -5.229717
# 148603  ...         Garen vs Wukong        6.697009          1.907745
# 148604  ...      Malphite vs Wukong        0.934120          1.782683
# 148605  ...      Darius vs Renekton             NaN          2.587992
# 148606  ...          Yasuo vs Quinn       -1.125989               NaN
# 148607  ...      Pantheon vs Irelia        4.708520          1.828822
# 148609  ...       Nasus vs Vladimir        0.293542          1.907745
# 148610  ...           Garen vs Gnar        0.293542          0.000000
# 148611  ...     Nasus vs Tahm Kench             NaN          7.142857
# 148612  ...       Renekton vs Fiora       -0.291579         -5.229717
# 148613  ...            Jax vs Nasus        2.784504               NaN
# 148614  ...          Fiora vs Riven        0.532878         -1.907745
# 148615  ...    Sejuani vs Jarvan IV        1.125989          1.747312
# 148616  ...         Darius vs Garen       -6.882591               NaN
# 148617  ...   Malphite vs Jarvan IV       -0.934120         -1.148225
# 148619  ...    Jarvan IV vs Hecarim        1.125989         -2.999294
# 148620  ...       Malphite vs Garen        0.532878         -1.528384
# 148621  ...        Gnar vs Vladimir        1.825467          1.907745
# 148623  ...        Poppy vs ChoGath        0.981524          1.703407
# 148624  ...           Ryze vs Garen        4.708520               NaN
# 148625  ...       ChoGath vs Illaoi       -2.784504          0.513274
# 148626  ...       Volibear vs Nasus             NaN         -1.148225
# 148627  ...     Malphite vs DrMundo        2.784504               NaN
# 148628  ...     Renekton vs Hecarim        2.064632          5.617978
# 148629  ...       Malphite vs Riven       -0.579710               NaN
# 148630  ...          Nasus vs Teemo        0.934120         -5.229717
# 148631  ...          Rumble vs Gnar        1.125989               NaN
# 148632  ...         Darius vs Nasus             NaN         -4.142357
# 148633  ...        Malphite vs Olaf       -2.784504         -2.999294
#
#         jungle_vs_score  mid_vs_score  top_vs_score     teammates_jungle_mid  \
# 0                   NaN     -5.040000      1.256281         Warwick & Viktor
# 1             -4.255319      4.633205           NaN          Evelynn & Yasuo
# 2              0.352941     -1.333010           NaN              Amumu & Lux
# 3                   NaN      1.054852           NaN         Wukong & Orianna
# 4              4.265949      1.525719     -0.588235           Warwick & Ahri
# 5             -0.891089           NaN      4.375000      Master Yi & Karthus
# 6             -0.891089           NaN           NaN       Master Yi & Lucian
# 7              4.265949      0.666667           NaN            Warwick & Lux
# 8             -2.098765           NaN      2.901024          Sejuani & Akali
# 10             2.098765           NaN           NaN         Warwick & Anivia
# 11                  NaN           NaN      3.046595           Warwick & Fizz
# 13            -2.677279           NaN      1.993068          KhaZix & Ezreal
# 14            -3.479381      3.516820           NaN             Graves & Lux
# 15                  NaN      4.773869           NaN        Sejuani & Orianna
# 16            -1.457574      4.299754           NaN        Graves & Vladimir
# 17            -7.485030           NaN           NaN          Warwick & Akali
# 20            -4.265949           NaN      2.181208       Lee Sin & Katarina
# 21            -2.677279      3.910402     -0.746269         KhaZix & Orianna
# 23                  NaN           NaN      4.854369          Warwick & Galio
# 24                  NaN      5.747126     -2.153110             Fizz & Annie
# 25             0.476190           NaN           NaN            Lee Sin & Zed
# 26                  NaN           NaN     -1.247601               Olaf & Lux
# 27            -1.320755     -3.408360      3.551913         Graves & Orianna
# 29                  NaN      3.154362           NaN           Sejuani & Ahri
# 30            -0.891089           NaN           NaN     Master Yi & Vladimir
# 31             5.921053      2.763819           NaN           Warwick & Ahri
# 32                  NaN           NaN           NaN             Akali & Ekko
# 33                  NaN      4.181818           NaN         Nocturne & Yasuo
# 34             1.777778           NaN     -7.718121           Warwick & Ekko
# 35             2.098765           NaN           NaN        Warwick & Morgana
# ...                 ...           ...           ...                      ...
# 148601         1.079137           NaN     -2.577320        Lee Sin & Morgana
# 148602              NaN     -5.567686     -2.579365             RekSai & Zed
# 148603        -1.456311           NaN           NaN         Rengar & ChoGath
# 148604        -2.375566     -1.131222           NaN           Lee Sin & Fizz
# 148605              NaN           NaN     -0.352941             Udyr & Brand
# 148606         5.623269     -0.624291           NaN           Amumu & Syndra
# 148607         5.813953           NaN     -3.403141        Master Yi & Annie
# 148609              NaN     -5.148741           NaN        Jarvan IV & Brand
# 148610              NaN           NaN           NaN    Rengar & Heimerdinger
# 148611         4.069767           NaN           NaN       Master Yi & Veigar
# 148612              NaN           NaN     -2.365237         Diana & Katarina
# 148613              NaN     -3.910402      2.964427              Shaco & Zed
# 148614              NaN      5.000000     -1.934827      Tahm Kench & Veigar
# 148615              NaN      3.852814           NaN              Udyr & Ahri
# 148616              NaN     -1.785714      2.017937               Ekko & Zed
# 148617              NaN     -5.567686           NaN            Trundle & Zed
# 148619              NaN      3.408360           NaN              Fizz & Ahri
# 148620        -0.080515           NaN      4.248366           Udyr & LeBlanc
# 148621              NaN      5.194805           NaN            Vi & Malzahar
# 148623         7.506361           NaN           NaN   Master Yi & Cassiopeia
# 148624        -3.103448           NaN           NaN              Elise & Zed
# 148625              NaN      4.181818           NaN           Twitch & Yasuo
# 148626         1.939826           NaN           NaN              Jax & Teemo
# 148627         4.069767     -0.793651           NaN       Master Yi & Veigar
# 148628         4.608455     -1.525719           NaN            Shaco & Yasuo
# 148629        -2.375566     -0.501672      1.538462           Lee Sin & Ekko
# 148630              NaN      5.263158     -4.754098          Warwick & Ziggs
# 148631              NaN      5.515588           NaN           Nidalee & Ekko
# 148632        -0.959488      1.242236      7.517900           Lee Sin & Ekko
# 148633              NaN     -7.635468           NaN  Xin Zhao & Twisted Fate
#
#             teammates_carry_sup  teammates_carry_sup_score  \
# 0                 Draven & Nami                   1.720183
# 1            Cassiopeia & Ziggs                        NaN
# 2                Draven & Janna                   4.726688
# 3                 Caitlyn & Zac                        NaN
# 4         Miss Fortune & Thresh                   2.794562
# 5                Lucian & Taric                  -0.577367
# 6                 Jinx & Thresh                   0.314465
# 7                 Ashe & Zilean                   8.167331
# 8                KogMaw & Janna                   6.735341
# 10           Tristana & Alistar                   0.000000
# 11               Caitlyn & Bard                   3.806228
# 13               Caitlyn & Nami                   0.716981
# 14         Miss Fortune & Leona                   7.502420
# 15                Vayne & Leona                  -1.600610
# 16          Draven & Blitzcrank                   2.462121
# 17                 Xayah & Bard                   2.114598
# 20              Caitlyn & Janna                   3.355155
# 21                 Jhin & Braum                  -4.166667
# 23       Miss Fortune & Morgana                   0.442478
# 24             Caitlyn & Thresh                   0.986005
# 25               Jinx & Morgana                   0.312500
# 26               Caitlyn & Nami                   0.716981
# 27                 Jinx & Galio                  -4.098361
# 29                Ezreal & Sona                  -2.211435
# 30                 Ashe & Annie                  -6.953642
# 31      Miss Fortune & Nautilus                   0.169492
# 32               Lucian & Taric                  -0.577367
# 33                Vayne & Braum                   2.511848
# 34                 Vayne & Lulu                   1.597938
# 35               Caitlyn & Bard                   3.806228
# ...                         ...                        ...
# 148601           Lucian & Janna                   1.869159
# 148602         Ezreal & Morgana                  -5.109489
# 148603     Miss Fortune & Janna                   2.024291
# 148604         Tristana & Janna                   2.161785
# 148605            Corki & Janna                   6.310680
# 148606           Lucian & Brand                   0.418888
# 148607           Sivir & Thresh                  -1.994092
# 148609         Tristana & Janna                   2.161785
# 148610         Tristana & Braum                  -1.406650
# 148611            Sivir & Janna                   4.794521
# 148612        Caitlyn & Morgana                   3.171577
# 148613          Jinx & Malphite                  -6.164384
# 148614          Lucian & Thresh                   0.284222
# 148615    Tristana & Blitzcrank                   2.893891
# 148616           Ezreal & Poppy                        NaN
# 148617          Vayne & Alistar                  -1.139601
# 148619       Tristana & Morgana                  -4.529915
# 148620           Lucian & Braum                  -0.795672
# 148621     Miss Fortune & Janna                   2.024291
# 148623           Caitlyn & Sona                   1.978320
# 148624         Sivir & Malphite                        NaN
# 148625    Tristana & Blitzcrank                   2.893891
# 148626        Kindred & Alistar                        NaN
# 148627             Jinx & Poppy                   0.704225
# 148628         Tristana & Braum                  -1.406650
# 148629         Ezreal & ChoGath                        NaN
# 148630       Tristana & Morgana                  -4.529915
# 148631        Tristana & Rammus                        NaN
# 148632          Kindred & Braum                        NaN
# 148633       Tristana & Morgana                  -4.529915
#
#         teammates_jungle_mid_score
# 0                        -3.488372
# 1                        -1.592357
# 2                         5.032468
# 3                        -2.941176
# 4                         2.766532
# 5                         3.488372
# 6                         3.225806
# 7                         3.229974
# 8                        -0.793651
# 10                        3.036437
# 11                        3.333333
# 13                       -5.405405
# 14                       -0.758460
# 15                        2.068474
# 16                        0.432277
# 17                        1.086957
# 20                        0.302216
# 21                        0.751880
# 23                             NaN
# 24                             NaN
# 25                       -6.224162
# 26                       -0.746269
# 27                       -5.810617
# 29                        3.916005
# 30                       -0.450450
# 31                        2.766532
# 32                             NaN
# 33                        1.923077
# 34                        3.859964
# 35                        8.536585
# ...                            ...
# 148601                   -2.488688
# 148602                   -3.246753
# 148603                         NaN
# 148604                   -2.059134
# 148605                    2.941176
# 148606                    4.791155
# 148607                    5.763240
# 148609                   -4.651163
# 148610                         NaN
# 148611                    0.177936
# 148612                         NaN
# 148613                   -2.981651
# 148614                         NaN
# 148615                    2.034884
# 148616                  -11.313869
# 148617                         NaN
# 148619                   -1.020408
# 148620                   -7.142857
# 148621                   -6.250000
# 148623                   -4.276316
# 148624                   -2.433817
# 148625                   -2.671756
# 148626                         NaN
# 148627                    0.177936
# 148628                    3.237410
# 148629                   -1.795143
# 148630                    5.018587
# 148631                   -3.174603
# 148632                   -1.795143
# 148633                   -0.476190
#
# [120498 rows x 94 columns]

# %% [markdown]
# ### 存储特征csv

# %%
feature_hero_dcdd_riva_teama.to_csv('feature_hero_dcdd_riva_teama.csv',index =False)

# %%
feature_hero_dcdd_riva_teama = pd.read_csv('feature_hero_dcdd_riva_teama.csv')

# %%
feature_hero_dcdd_riva_teama.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148634 entries, 0 to 148633
# Data columns (total 94 columns):
# matchid                         148634 non-null int64
# 1 - DUO_CARRY                   148634 non-null object
# 1 - DUO_SUPPORT                 148634 non-null object
# 1 - JUNGLE                      148634 non-null object
# 1 - MID                         148634 non-null object
# 1 - TOP                         148634 non-null object
# 2 - DUO_CARRY                   148634 non-null object
# 2 - DUO_SUPPORT                 148634 non-null object
# 2 - JUNGLE                      148634 non-null object
# 2 - MID                         148634 non-null object
# 2 - TOP                         148634 non-null object
# T1 win                          148634 non-null float64
# 1_total_kills                   148634 non-null float64
# 2_total_kills                   148634 non-null float64
# 1 - MID_kills                   148634 non-null float64
# 1 - MID_deaths                  148634 non-null float64
# 1 - MID_assists                 148634 non-null float64
# 1 - MID_dmgtoturrets            148634 non-null float64
# 1 - MID_visionscore             148634 non-null float64
# 1 - MID_KDA                     148634 non-null float64
# 1 - TOP_kills                   148634 non-null float64
# 1 - TOP_deaths                  148634 non-null float64
# 1 - TOP_assists                 148634 non-null float64
# 1 - TOP_dmgtoturrets            148634 non-null float64
# 1 - TOP_visionscore             148634 non-null float64
# 1 - TOP_KDA                     148634 non-null float64
# 1 - DUO_SUPPORT_kills           148634 non-null float64
# 1 - DUO_SUPPORT_deaths          148634 non-null float64
# 1 - DUO_SUPPORT_assists         148634 non-null float64
# 1 - DUO_SUPPORT_dmgtoturrets    148634 non-null float64
# 1 - DUO_SUPPORT_visionscore     148634 non-null float64
# 1 - DUO_SUPPORT_KDA             148634 non-null float64
# 1 - DUO_CARRY_kills             148634 non-null float64
# 1 - DUO_CARRY_deaths            148634 non-null float64
# 1 - DUO_CARRY_assists           148634 non-null float64
# 1 - DUO_CARRY_dmgtoturrets      148634 non-null float64
# 1 - DUO_CARRY_visionscore       148634 non-null float64
# 1 - DUO_CARRY_KDA               148634 non-null float64
# 1 - JUNGLE_kills                148634 non-null float64
# 1 - JUNGLE_deaths               148634 non-null float64
# 1 - JUNGLE_assists              148634 non-null float64
# 1 - JUNGLE_dmgtoturrets         148634 non-null float64
# 1 - JUNGLE_visionscore          148634 non-null float64
# 1 - JUNGLE_KDA                  148634 non-null float64
# 2 - MID_kills                   148634 non-null float64
# 2 - MID_deaths                  148634 non-null float64
# 2 - MID_assists                 148634 non-null float64
# 2 - MID_dmgtoturrets            148634 non-null float64
# 2 - MID_visionscore             148634 non-null float64
# 2 - MID_KDA                     148634 non-null float64
# 2 - TOP_kills                   148634 non-null float64
# 2 - TOP_deaths                  148634 non-null float64
# 2 - TOP_assists                 148634 non-null float64
# 2 - TOP_dmgtoturrets            148634 non-null float64
# 2 - TOP_visionscore             148634 non-null float64
# 2 - TOP_KDA                     148634 non-null float64
# 2 - DUO_SUPPORT_kills           148634 non-null float64
# 2 - DUO_SUPPORT_deaths          148634 non-null float64
# 2 - DUO_SUPPORT_assists         148634 non-null float64
# 2 - DUO_SUPPORT_dmgtoturrets    148634 non-null float64
# 2 - DUO_SUPPORT_visionscore     148634 non-null float64
# 2 - DUO_SUPPORT_KDA             148634 non-null float64
# 2 - DUO_CARRY_kills             148634 non-null float64
# 2 - DUO_CARRY_deaths            148634 non-null float64
# 2 - DUO_CARRY_assists           148634 non-null float64
# 2 - DUO_CARRY_dmgtoturrets      148634 non-null float64
# 2 - DUO_CARRY_visionscore       148634 non-null float64
# 2 - DUO_CARRY_KDA               148634 non-null float64
# 2 - JUNGLE_kills                148634 non-null float64
# 2 - JUNGLE_deaths               148634 non-null float64
# 2 - JUNGLE_assists              148634 non-null float64
# 2 - JUNGLE_dmgtoturrets         148634 non-null float64
# 2 - JUNGLE_visionscore          148634 non-null float64
# 2 - JUNGLE_KDA                  148634 non-null float64
# 1_ad_dc                         148634 non-null float64
# 2_ad_dc                         148634 non-null float64
# 1_mid_dc                        148634 non-null float64
# 2_mid_dc                        148634 non-null float64
# 1_top_dd                        148634 non-null float64
# 2_top_dd                        148634 non-null float64
# carry_vs                        148634 non-null object
# support_vs                      148634 non-null object
# jungle_vs                       148634 non-null object
# mid_vs                          148634 non-null object
# top_vs                          148634 non-null object
# carry_vs_score                  142601 non-null float64
# support_vs_score                125402 non-null float64
# jungle_vs_score                 104634 non-null float64
# mid_vs_score                    99632 non-null float64
# top_vs_score                    71723 non-null float64
# teammates_jungle_mid            148634 non-null object
# teammates_carry_sup             148634 non-null object
# teammates_carry_sup_score       140914 non-null float64
# teammates_jungle_mid_score      124787 non-null float64
# dtypes: float64(76), int64(1), object(17)
# memory usage: 106.6+ MB
